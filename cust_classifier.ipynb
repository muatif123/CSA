# %% [markdown]
# ### 🎯 Inference Notebook: Predict Customer Satisfaction

# %%
import pandas as pd
import numpy as np
import pickle, joblib
from sklearn.ensemble import RandomForestClassifier

# %%
# Load real-world survey data for prediction
rd = pd.read_excel('Book1.xlsx')  # <-- Replace with your actual file name
rd.head()
# Out:
#                  Q1                                                 Q2  \
# 0  2-3 times a week  Customer service; Variety of products; Quality...
# 1  2-3 times a week  Quality of products; Location; Customer servic...
# 2      Once a month                                   Customer service
#
#            Q3  Q4                                                 Q5  \
# 0      ₹2000+   4                          Enhanced customer service
# 1  ₹500–₹1000   2  Enhanced customer service; Better promotions/o...
# 2  ₹500–₹1000   3  Better promotions/offers; Enhanced customer se...
#
#                                                   Q6  \
# 0          Mobile Payment (e.g. Google Pay, PhonePe)
# 1  Cash; Credit/Debit Card; Mobile Payment (e.g. ...
# 2                            Credit/Debit Card; Cash
#
#                                                   Q7  Q8  Q9  Q10
# 0  Special Discounts for Regular Customers; Other...   9   9    4
# 1  Buy One Get One Free; Special Discounts for Re...   9   4    3
# 2  Buy One Get One Free; Special Discounts for Re...   2   2    5

# %%
# Encode categorical features as done during training
q1_map = {'Once a week': 1, '2-3 times a week': 2, 'Once a month': 3, 'Rarely': 4}
q3_map = {'₹100–₹500': 1, '₹500–₹1000': 2, '₹1000–₹2000': 3, '₹2000+': 4}
rd['Q1'] = rd['Q1'].map(q1_map)
rd['Q3'] = rd['Q3'].map(q3_map)
rd['Q4'] = rd['Q4'].astype(int)
rd['Q8'] = rd['Q8'].astype(int)
rd['Q9'] = rd['Q9'].astype(int)
rd['Q10'] = rd['Q10'].astype(int)

# %%
rd.columns[rd.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
rd = rd.loc[:, ~rd.columns.duplicated()]
rd.head()
# Out:
#    Q1                                                 Q2  Q3  Q4  \
# 0   2  Customer service; Variety of products; Quality...   4   4
# 1   2  Quality of products; Location; Customer servic...   2   2
# 2   3                                   Customer service   2   3
#
#                                                   Q5  \
# 0                          Enhanced customer service
# 1  Enhanced customer service; Better promotions/o...
# 2  Better promotions/offers; Enhanced customer se...
#
#                                                   Q6  \
# 0          Mobile Payment (e.g. Google Pay, PhonePe)
# 1  Cash; Credit/Debit Card; Mobile Payment (e.g. ...
# 2                            Credit/Debit Card; Cash
#
#                                                   Q7  Q8  Q9  Q10
# 0  Special Discounts for Regular Customers; Other...   9   9    4
# 1  Buy One Get One Free; Special Discounts for Re...   9   4    3
# 2  Buy One Get One Free; Special Discounts for Re...   2   2    5

# %%
# Drop rows with missing values (if any)
rd.dropna(inplace=True)
rd
# Out:
#    Q1                                                 Q2  Q3  Q4  \
# 0   2  Customer service; Variety of products; Quality...   4   4
# 1   2  Quality of products; Location; Customer servic...   2   2
# 2   3                                   Customer service   2   3
#
#                                                   Q5  \
# 0                          Enhanced customer service
# 1  Enhanced customer service; Better promotions/o...
# 2  Better promotions/offers; Enhanced customer se...
#
#                                                   Q6  \
# 0          Mobile Payment (e.g. Google Pay, PhonePe)
# 1  Cash; Credit/Debit Card; Mobile Payment (e.g. ...
# 2                            Credit/Debit Card; Cash
#
#                                                   Q7  Q8  Q9  Q10
# 0  Special Discounts for Regular Customers; Other...   9   9    4
# 1  Buy One Get One Free; Special Discounts for Re...   9   4    3
# 2  Buy One Get One Free; Special Discounts for Re...   2   2    5

# %%
# Load trained RandomForest model
with open('customer_classifier_RF.pkl', 'rb') as f:
    model = joblib.load(f)

print(type(model))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
# Run predictions
X_real = rd[['Q1', 'Q3', 'Q4', 'Q8', 'Q9', 'Q10']]
rd['Predicted_Cust_Satisfaction'] = model.predict(X_real)
#rd[['Q1', 'Q3', 'Q4', 'Q8', 'Q9', 'Q10', 'Predicted_Cust_Satisfaction']]
rd
# Out:
#    Q1                                                 Q2  Q3  Q4  \
# 0   2  Customer service; Variety of products; Quality...   4   4
# 1   2  Quality of products; Location; Customer servic...   2   2
# 2   3                                   Customer service   2   3
#
#                                                   Q5  \
# 0                          Enhanced customer service
# 1  Enhanced customer service; Better promotions/o...
# 2  Better promotions/offers; Enhanced customer se...
#
#                                                   Q6  \
# 0          Mobile Payment (e.g. Google Pay, PhonePe)
# 1  Cash; Credit/Debit Card; Mobile Payment (e.g. ...
# 2                            Credit/Debit Card; Cash
#
#                                                   Q7  Q8  Q9  Q10  \
# 0  Special Discounts for Regular Customers; Other...   9   9    4
# 1  Buy One Get One Free; Special Discounts for Re...   9   4    3
# 2  Buy One Get One Free; Special Discounts for Re...   2   2    5
#
#    Predicted_Cust_Satisfaction
# 0                            1
# 1                            0
# 2                            0
